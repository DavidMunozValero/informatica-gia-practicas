# %% [markdown]
# # Tema 5.1: Ejercicios
#
# Funciones
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Área y volumen de una esfera
#
# Define una función `area_y_volumen_esfera(radio)` que devuelva una tupla `(area, volumen)` usando las fórmulas $A = 4\pi r^2$ y $V = \frac{4}{3}\pi r^3$. Usa `3.1416` como aproximación de $\pi$.
#
# Ejemplo: `area_y_volumen_esfera(3)` → `(113.0976, 113.0976)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Conversiones aeronáuticas
#
# Define tres funciones de conversión de unidades aeronáuticas:
#
# - `nudos_a_kmh(nudos)`
# - `pies_a_metros(pies)`
# - `millas_nauticas_a_km(millas)`
#
# Luego, define `convierte(velocidad_nudos, altitud_pies, distancia_millas)` que devuelva una tupla `(km_h, metros, km)`.
#
# Ejemplo: `convierte(120, 10000, 500)` → `(222.24, 3048.0, 926.0)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Factorial iterativo y recursivo
#
# Define `factorial_iterativo(n)` y `factorial_recursivo(n)`. Ambas deben devolver el factorial de un entero `n >= 0`. Comprueba que dan el mismo resultado para `n = 7`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Contar vocales con filter
#
# Define `contar_vocales(texto)` que devuelva el número de vocales (mayúsculas o minúsculas) de una cadena. Resuélvelo usando `filter` y una función `lambda`.
#
# Ejemplos:
# - `contar_vocales("Aeroespacial")` → `7`
# - `contar_vocales("Python")` → `1`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Saludo multilingüe
#
# Define `saludo_idioma(nombre, idioma="es")` que devuelva un saludo en español, inglés o francés según el parámetro `idioma` (`"es"`, `"en"` o `"fr"`). Si el idioma no está soportado, devuelve el saludo en español.
#
# Ejemplos:
# - `saludo_idioma("Ana")` → `"Hola, Ana"`
# - `saludo_idioma("Ana", "en")` → `"Hello, Ana"`
# - `saludo_idioma("Ana", "fr")` → `"Bonjour, Ana"`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Resumen aerodinámico
#
# Define `fuerza_arrastre(rho, v, cd, area)` que calcule la fuerza de arrastre $F_d = \frac{1}{2} \rho v^2 C_d A$. Luego define `energia_cinetica(masa, velocidad)` como $E_c = \frac{1}{2} m v^2$. Finalmente, escribe una función `resumen_aerodinamico(masa, rho, v, cd, area)` que devuelva un diccionario con las claves `"fuerza_arrastre"` y `"energia_cinetica"`.
#
# Ejemplo: `resumen_aerodinamico(1000, 1.225, 100, 0.3, 10)` → `{'fuerza_arrastre': 18375.0, 'energia_cinetica': 5000000.0}`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
