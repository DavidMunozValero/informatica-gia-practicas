# %% [markdown]
# # Tema 5.4: Ejercicios
#
# Excepciones y aserciones
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Conversión segura a entero
#
# Escribe una función `lee_entero(entrada)` que intente convertir `entrada` a entero, capture `ValueError` si no es posible y devuelva `None` en ese caso.
#
# Ejemplos:
# - `lee_entero("42")` → `42`
# - `lee_entero("hola")` → `None`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Apertura segura de archivo
#
# Define una función `abre_archivo(nombre)` que intente abrir un archivo en modo lectura y devolver su contenido. Si el archivo no existe, captura `FileNotFoundError` y devuelve `"Archivo no encontrado"`. En cualquier caso, imprime `"Intento de lectura finalizado"`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Excepción personalizada
#
# Crea una excepción `VelocidadInvalidaError` y una función `valida_velocidad(v)` que lance esta excepción si `v` es negativa o mayor que 1000 m/s.
#
# Ejemplo: `valida_velocidad(1500)` debe lanzar `VelocidadInvalidaError`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: except específico
#
# Corrige el siguiente código para que capture específicamente `ZeroDivisionError` y no use un `except:` genérico.
#
# ```python
# def cociente(a, b):
#     try:
#         return a / b
#     except:
#         return 0
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Acceso seguro a diccionario
#
# Escribe una función `accede_seguro(diccionario, clave)` que devuelva el valor si la clave existe, o `"Clave no encontrada"` si no. Resuélvelo de dos formas: con `try`/`except KeyError` y con `.get()`.
#
# ```python
# config = {"modo": "manual", "altitud": 10000}
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: assert vs raise
#
# ¿Cuál es la diferencia entre `assert` y `raise`? Escribe un ejemplo en el que usarías `assert` y otro en el que usarías `raise`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
