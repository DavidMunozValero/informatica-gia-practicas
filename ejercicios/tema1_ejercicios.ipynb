# %% [markdown]
# # Tema 1: Ejercicios
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.

# %% [markdown]
# ## Ejercicio 1: Conversión a binario
#
# Convierte el número $156_{10}$ a binario utilizando el método de divisiones sucesivas. Programa una función `decimal_a_binario(n)` que reciba un entero decimal y devuelva su representación binaria como cadena.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Conversión desde hexadecimal
#
# Convierte $3C_{16}$ a decimal y a binario. Programa una función `hex_a_todo(h)` que reciba una cadena hexadecimal y devuelva una tupla `(decimal, binario)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Conversión binario → hexadecimal y octal
#
# Convierte $1101\ 1010_2$ a hexadecimal y a octal. Programa una función `binario_a_hex_oct(b)` que reciba una cadena binaria y devuelva `(hexadecimal, octal)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Verificación con Python
#
# Utiliza las funciones nativas de Python (`bin()`, `oct()`, `hex()`, `int()`) para verificar que $255_{10} = 11111111_2 = FF_{16} = 377_8$.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Descomposición polinómica
#
# Programa una función `descomponer(numero_str, base)` que reciba un número como cadena y su base, y devuelva la descomposición polinómica como cadena. Por ejemplo, `descomponer('1011', 2)` debe devolver `'1·2^3 + 0·2^2 + 1·2^1 + 1·2^0'`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
