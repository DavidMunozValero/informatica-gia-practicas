# %% [markdown]
# # Tema 4.2: Ejercicios
#
# Listas avanzadas
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Cambia negativos
#
# Define `cambia_negativos(L)` que reciba una lista de números y devuelva una **nueva lista** en la que los números negativos se hayan sustituido por `0`. La lista original no debe modificarse.
#
# Ejemplos:
# - `cambia_negativos([1, -2, 3, -4, 5])` → `[1, 0, 3, 0, 5]`
# - `cambia_negativos([-1, -2, -3])` → `[0, 0, 0]`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Borra duplicados
#
# Define `borra_duplicados(L)` que reciba una lista y elimine los elementos duplicados, conservando solo la primera aparición de cada valor. La lista debe modificarse **in situ**; la función no devuelve nada.
#
# Ejemplo:
# ```python
# L = [1, 2, 2, 3, 4, 4, 4, 5]
# borra_duplicados(L)
# print(L)  # [1, 2, 3, 4, 5]
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Transpuesta de una matriz
#
# Define `transpuesta(M)` que reciba una matriz representada como lista de listas y devuelva su transpuesta. Debes usar una **list comprehension anidada**.
#
# Ejemplo:
# ```python
# M = [
#     [1, 2, 3],
#     [4, 5, 6]
# ]
# print(transpuesta(M))  # [[1, 4], [2, 5], [3, 6]]
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Cuadrado mágico de Lo Shu
#
# Define `es_cuadrado_magico(M)` que devuelva `True` si `M` es un cuadrado mágico de orden 3 (todas las filas, columnas y diagonales suman lo mismo).
#
# Ejemplos:
# ```python
# lo_shu = [
#     [4, 9, 2],
#     [3, 5, 7],
#     [8, 1, 6]
# ]
# print(es_cuadrado_magico(lo_shu))  # True
# print(es_cuadrado_magico([[1, 2, 3], [4, 5, 6], [7, 8, 9]]))  # False
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Filtra y duplica
#
# Define `filtra_y_duplica(L)` que reciba una lista de enteros y devuelva una nueva lista con el doble de cada elemento positivo, ignorando ceros y negativos. Resuélvelo con una list comprehension.
#
# Ejemplo: `filtra_y_duplica([1, -2, 0, 3, -4, 5])` → `[2, 6, 10]`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Cálculo del IRPF
#
# Define `irpf(dinero)` que calcule el impuesto sobre la renta usando los siguientes tramos simplificados:
#
# | Tramo (euros) | Tipo impositivo |
# |---|---|
# | Hasta 12 450 | 19 % |
# | 12 450 – 20 200 | 24 % |
# | 20 200 – 35 200 | 30 % |
# | 35 200 – 60 000 | 37 % |
# | Más de 60 000 | 45 % |
#
# El impuesto se calcula de forma progresiva: solo la parte de renta que cae en cada tramo se grava al tipo correspondiente. Usa dos listas paralelas, una con los límites y otra con los tipos.
#
# Ejemplos:
# - `irpf(10000)` → `1900.0`
# - `irpf(20000)` → `3882.5`
# - `irpf(50000)` → `12626.5`

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
