# %% [markdown]
# # Tema 3.1: Ejercicios
#
# Introducción a Python
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Producto y potencia
#
# Escribe un programa que calcule el producto `5 * 3` y lo muestre por pantalla. Después, modifica el programa para que calcule también `5 ** 3` (potencia) y observa la diferencia.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Función `saludo()`
#
# Define una función `saludo()` que, al ser invocada, imprima por pantalla `"¡Hola, clase!"`. Llama a la función dos veces.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Función `restar(a, b)` con `return`
#
# Define una función `restar(a, b)` que **devuelva** (no imprima) la resta `a - b`. Llámala con `restar(10, 4)`, guarda el resultado en una variable `r` y luego imprime `r`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Conversión de nudos a km/h
#
# Define una función `nudos_a_kmh(velocidad_kt)` que convierta una velocidad en nudos a km/h (1 kt = 1,852 km/h). Pruébala con la velocidad de un avión de línea en crucero (≈ 450 kt) y muestra el resultado con un f-string.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Polimorfismo de `+`
#
# Define una función `suma_tres(a, b, c)` que devuelva `a + b + c`. Comprueba qué pasa al llamarla con `suma_tres("1", "2", "3")` y con `suma_tres(1, 2, 3)`. Explica por qué dan resultados distintos.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
