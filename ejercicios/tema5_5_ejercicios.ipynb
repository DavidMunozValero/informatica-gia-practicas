# %% [markdown]
# # Tema 5.5: Ejercicios
#
# Programación orientada a objetos
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Clase Punto2D
#
# Define una clase `Punto2D` con atributos `x` e `y`, un método `distancia_origen()` y un `__str__` que devuelva `(x, y)`. Crea dos puntos y muestra sus representaciones.
#
# Ejemplo: `Punto2D(3, 4).distancia_origen()` → `5.0`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Cuenta bancaria encapsulada
#
# Define una clase `CuentaBancaria` con atributo `_saldo` y métodos `ingresar(cantidad)`, `retirar(cantidad)` y `saldo()`. Asegúrate de que no se pueda retirar más dinero del disponible.
#
# Ejemplo:
# - `c = CuentaBancaria(100); c.ingresar(50); c.retirar(30); print(c.saldo())` → `120`
# - `c.retirar(200)` no debe cambiar el saldo.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Polimorfismo con animales
#
# Crea una jerarquía con una clase base `Animal` y dos clases hijas `Perro` y `Gato`. Cada una debe tener un método `sonido()` que imprima el sonido correspondiente. Luego, escribe una función `hacer_sonar(animal)` que aproveche el polimorfismo.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Rectángulo y Cuadrado
#
# Define una clase `Rectangulo` con atributos `base` y `altura`, y métodos `area()` y `perimetro()`. Luego define una clase `Cuadrado` que herede de `Rectangulo` y aproveche que base y altura son iguales.
#
# Ejemplo:
# - `Rectangulo(4, 5).area()` → `20`
# - `Cuadrado(3).area()` → `9`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Igualdad de puntos
#
# Implementa `__eq__` en la clase `Punto2D` del Ejercicio 1 para que dos puntos sean iguales si tienen las mismas coordenadas. Comprueba que `(1, 2) == (1, 2)` y que `(1, 2) != (1, 3)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Sensores de un satélite
#
# Diseña una jerarquía de clases para modelar sensores de un satélite. Define una clase base `Sensor` con método `leer()` y atributos `id` y `estado`. Define `SensorTemperatura` y `SensorRadiacion` que hereden de `Sensor` y sobrescriban `leer()` para devolver un mensaje distinto.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
