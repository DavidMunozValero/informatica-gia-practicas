# %% [markdown]
# # Tema 5.6: Ejercicios
#
# Métodos de búsqueda de solución
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (`Archivo > Guardar una copia en Drive`) antes de trabajar.

# %% [markdown]
# ## Ejercicio 1: Búsqueda exhaustiva de una raíz
#
# Implementa `busqueda_exhaustiva_raiz(n, epsilon)` que encuentre una aproximación de $\sqrt{n}$ probando valores desde 0 con incrementos de `epsilon`. Comprueba el resultado con `math.sqrt(2)`.

# %%
import math

def busqueda_exhaustiva_raiz(n, epsilon):
    pass  # Tu código aquí

print(busqueda_exhaustiva_raiz(2, 0.001))
print(math.sqrt(2))

# %% [markdown]
# ## Ejercicio 2: Bisección
#
# Implementa `biseccion(f, a, b, epsilon)` y úsala para calcular una raíz de $f(x) = x^3 - x - 2$ en el intervalo $[1, 2]$ con tolerancia $10^{-5}$.

# %%
def biseccion(f, a, b, epsilon):
    pass  # Tu código aquí

print(biseccion(lambda x: x**3 - x - 2, 1, 2, 1e-5))

# %% [markdown]
# ## Ejercicio 3: Newton-Raphson
#
# Implementa `newton_raphson(f, df, x0, epsilon)` y úsala para la raíz de $f(x) = x^3 - x - 2$ partiendo de $x_0 = 2$.

# %%
def newton_raphson(f, df, x0, epsilon):
    pass  # Tu código aquí

f = lambda x: x**3 - x - 2
df = lambda x: 3*x**2 - 1
print(newton_raphson(f, df, 2, 1e-5))

# %% [markdown]
# ## Ejercicio 4: Comparar iteraciones
#
# Compara el número de iteraciones para $\sqrt{2}$ con bisección (intervalo $[1, 2]$) y Newton-Raphson ($x_0 = 2$), tolerancia $10^{-6}$. Añade contadores a cada función.

# %%
def biseccion_conteo(f, a, b, epsilon):
    pass

def newton_conteo(f, df, x0, epsilon):
    pass

print("Bisección:", biseccion_conteo(lambda x: x**2 - 2, 1, 2, 1e-6))
print("Newton:", newton_conteo(lambda x: x**2 - 2, lambda x: 2*x, 2, 1e-6))

# %% [markdown]
# ## Ejercicio 5: Suma top-down
#
# Implementa `suma_top_down(L)` que sume los elementos de una lista dividiéndola en mitades recursivamente.

# %%
def suma_top_down(L):
    pass  # Tu código aquí

print(suma_top_down([1, 2, 3, 4, 5, 6, 7, 8]))

# %% [markdown]
# ## Ejercicio 6: Radio orbital con Newton-Raphson
#
# Un satélite en órbita baja tiene velocidad $v = \sqrt{GM/r}$, con $GM = 3.986 \times 10^{14}$ m³/s². Usa Newton-Raphson para calcular el radio $r$ tal que $v = 7800$ m/s.

# %%
import math

GM = 3.986e14
v = 7800

# Resuelve GM/r - v**2 = 0 con Newton-Raphson
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
