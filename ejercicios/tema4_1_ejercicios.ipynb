# %% [markdown]
# # Tema 4.1: Ejercicios
#
# Listas
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Suma y extremos
#
# Define una función `suma_y_extremos(L)` que reciba una lista de números y devuelva una tupla `(suma, maximo, minimo)`. **No uses** las funciones integradas `sum`, `max` ni `min`; resuélvelo con un bucle.
#
# Ejemplo: `suma_y_extremos([3, 1, 4, 1, 5, 9, 2, 6])` debe devolver `(31, 9, 1)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Intercambio de extremos
#
# Define `intercambia_extremos(L)` que devuelva una **nueva lista** igual a `L` pero con el primer y el último elemento intercambiados. Si la lista tiene 0 o 1 elementos, devuélvela igual.
#
# Ejemplos:
# - `intercambia_extremos([1, 2, 3, 4, 5])` → `[5, 2, 3, 4, 1]`
# - `intercambia_extremos(["a", "b"])` → `["b", "a"]`
# - `intercambia_extremos([7])` → `[7]`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Sustituye los pares
#
# Define `sustituye_pares(L)` que reciba una lista de enteros y devuelva una nueva lista en la que todos los números pares se hayan sustituido por `0`. Los impares deben conservarse.
#
# Ejemplos:
# - `sustituye_pares([1, 2, 3, 4, 5, 6])` → `[1, 0, 3, 0, 5, 0]`
# - `sustituye_pares([2, 4, 6])` → `[0, 0, 0]`
# - `sustituye_pares([1, 3, 5])` → `[1, 3, 5]`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Media de notas
#
# Define `media_notas(notas)` que reciba una lista de notas (números entre 0 y 10) y devuelva la media. Si la lista está vacía, devuelve `0.0`.
#
# Ejemplos:
# - `media_notas([7.5, 8.0, 6.5, 9.0])` → `7.75`
# - `media_notas([])` → `0.0`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Filtra palabras
#
# Define `filtra_palabras(palabras)` que reciba una lista de cadenas y devuelva una nueva lista con aquellas palabras que tengan más de dos caracteres y cuya primera y última letra coincidan.
#
# Ejemplo: `filtra_palabras(["ala", "oso", "casa", "reloj", "anilina"])` → `["ala", "oso", "anilina"]`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Posiciones en MRUA
#
# Define `posiciones_mrua(t_inicial, t_final, dt, x0, v0, a)` que devuelva una lista con las posiciones de un objeto en MRUA desde `t_inicial` hasta `t_final` (incluido), con incrementos de `dt`. Usa la fórmula $x(t) = x_0 + v_0 t + \frac{1}{2} a t^2$.
#
# Ejemplo: `posiciones_mrua(0, 2, 0.5, 0, 0, 2)` → `[0.0, 0.25, 1.0, 2.25, 4.0]`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
