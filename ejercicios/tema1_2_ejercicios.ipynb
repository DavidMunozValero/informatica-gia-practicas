# %% [markdown]
# # Tema 1.2: Ejercicios
#
# Componentes de un Sistema Informático — Bloque B (Python)
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (`Archivo > Guardar una copia en Drive`) antes de trabajar. Los cambios en Colab no se guardan en el repositorio del curso.

# %% [markdown]
# ## Ejercicio A: Desplazamientos de bits
#
# Utiliza Python para verificar que $13 \ll 2 = 52$ y $13 \gg 1 = 6$. Muestra también la representación binaria de cada resultado.

# %%
# Verifica los desplazamientos
n = 13
# Tu solución aquí

# %% [markdown]
# ## Ejercicio B: Flags de un byte de estado
#
# Un byte de estado de un sensor aeronáutico contiene:
#
# - Bit 7: sensor válido.
# - Bit 3: alarma activa.
# - Bits 1-0: modo de operación (0=standby, 1=normal, 2=test).
#
# Dado el valor `0b10001010`, extrae si el sensor es válido, si hay alarma y el modo de operación.

# %%
estado = 0b10001010

sensor_valido = None  # bit 7
alarma = None         # bit 3
modo = None           # bits 1-0

print(f"Sensor válido: {sensor_valido}")
print(f"Alarma: {alarma}")
print(f"Modo: {modo}")

# %% [markdown]
# ## Ejercicio C: Manipulación de flags
#
# Dado el byte de estado `0b10110110`, escribe un programa que:
#
# 1. Extraiga los 4 bits menos significativos.
# 2. Compruebe si el bit 3 está activo.
# 3. Active el bit 0 sin modificar los demás.
# 4. Desactive el bit 7 sin modificar los demás.

# %%
estado = 0b10110110

nibble_bajo = 0
bit_3 = 0
activado = 0
desactivado = 0

print(f"Nibble bajo: {nibble_bajo:04b}")
print(f"Bit 3 activo: {bit_3}")
print(f"Activado bit 0: {activado:08b}")
print(f"Desactivado bit 7: {desactivado:08b}")

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
