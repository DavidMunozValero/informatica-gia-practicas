# %% [markdown]
# # Tema 5.2: Ejercicios
#
# Complejidad algorítmica
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Clasifica la complejidad
#
# Determina la complejidad asintótica de las siguientes funciones en notación Big-O. Justifica tu respuesta.
#
# ```python
# # a)
# def a(L):
#     return L[0]
#
# # b)
# def b(L):
#     for x in L:
#         print(x)
#
# # c)
# def c(L):
#     for i in range(len(L)):
#         for j in range(len(L)):
#             print(i, j)
# ```

# %%
# Tu solución aquí (puedes probar con listas de distinto tamaño)

# %% [markdown]
# ## Ejercicio 2: Búsqueda binaria con contador
#
# Implementa `busqueda_binaria(L, objetivo)` que devuelva el índice del objetivo en una lista ordenada, o `-1` si no está. Añade un contador que devuelva también el número de comparaciones realizadas.
#
# Ejemplo: `busqueda_binaria([1, 3, 5, 7, 9, 11, 13, 15], 7)` → `(3, 3)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Duplicados en O(n) vs O(n²)
#
# Define `tiene_duplicados_cuadratico(L)` que detecte si una lista tiene elementos repetidos usando un bucle anidado. Luego define `tiene_duplicados_lineal(L)` que use un `set`. Comprueba que ambas dan el mismo resultado para varias listas.
#
# Ejemplos:
# - `tiene_duplicados_cuadratico([1, 2, 3, 4, 5])` → `False`
# - `tiene_duplicados_lineal([1, 2, 3, 2, 5])` → `True`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Mejor y peor caso
#
# Define `primer_mayor_que(L, umbral)` que devuelva el primer elemento de la lista que sea mayor que `umbral`, o `None` si no hay ninguno. ¿Cuál es su complejidad en el peor caso? ¿Y en el mejor caso?
#
# Ejemplos:
# - `primer_mayor_que([1, 5, 8, 2, 9], 4)` → `5`
# - `primer_mayor_que([1, 2, 3], 5)` → `None`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Análisis de bucle condicional
#
# Dado el siguiente fragmento, indica su complejidad total y explica por qué.
#
# ```python
# def suma_pares_impares(L):
#     pares = 0
#     impares = 0
#     for x in L:
#         if x % 2 == 0:
#             pares += x
#         else:
#             impares += x
#     return pares, impares
# ```

# %%
# Tu solución aquí (opcional: probar con datos)

# %% [markdown]
# ## Ejercicio 6: Comparación lineal vs binaria
#
# Define funciones `busqueda_lineal_conteo(L, objetivo)` y `busqueda_binaria_conteo(L, objetivo)` que devuelvan el número de comparaciones realizadas. Luego define `medir_comparaciones(n)` que cree una lista ordenada de `0` a `n-1` y busque el elemento `-1` (no existe) con ambos algoritmos.
#
# Ejemplo: `medir_comparaciones(1000)` → `{'lineal': 1000, 'binaria': 10}`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
