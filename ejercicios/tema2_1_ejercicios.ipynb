# %% [markdown]
# # Tema 2.1: Ejercicios
#
# Sistemas Operativos — Bloque B (Python)
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (`Archivo > Guardar una copia en Drive`) antes de trabajar.

# %% [markdown]
# ## Ejercicio A: Inspección de archivo con pathlib
#
# Usa `pathlib` para crear un archivo de prueba e inspeccionar su tamaño, el modo en **octal** y — aplicando la máscara `0o777` — los permisos `rwx` efectivos.
#
# En Colab no están los `.qmd` del curso: crea tú el archivo (p. ej. `datos_vuelo.txt`).

# %%
from pathlib import Path

# Crea un archivo de prueba e inspecciona st_size y st_mode
archivo = Path("datos_vuelo.txt")
# Tu solución aquí

# %% [markdown]
# ## Ejercicio B: De permisos simbólicos a octal
#
# Programa una función `permisos_a_octal(modo_str)` que reciba una cadena simbólica de 9 caracteres como `rwxr-x--x` y devuelva el entero octal correspondiente (p. ej. `751`). Equivalencia: `r=4`, `w=2`, `x=1`, guion `-` = 0.

# %%
def permisos_a_octal(modo_str):
    pass  # Tu código aquí

print(permisos_a_octal("rwxr-x--x"))  # 751
print(permisos_a_octal("rw-r--r--"))  # 644
print(permisos_a_octal("rwxrwxrwx"))  # 777

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
