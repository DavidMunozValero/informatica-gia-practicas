# %% [markdown]
# # Tema 5.3: Ejercicios
#
# Prueba y depuración
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Clasifica los errores
#
# Clasifica los siguientes errores en **sintaxis**, **tiempo de ejecución** o **semánticos**:
#
# ```python
# # a)
# print("Hola" + 5)
#
# # b)
# def doble(x)
#     return x * 2
#
# # c)
# def area_cuadrado(lado):
#     return lado + lado
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Corrige todos_positivos
#
# La siguiente función debería devolver `True` si todos los elementos de una lista son positivos y `False` en caso contrario. Copia el código correcto y añade asserts que lo verifiquen.
#
# ```python
# def todos_positivos(L):
#     for x in L:
#         if x <= 0:
#             return False
#     return True
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Año bisiesto con asserts
#
# Escribe una función `es_bisiesto(año)` y una serie de `assert` que la prueben con casos normales y límite. Recuerda: un año es bisiesto si es divisible por 4, excepto si es divisible por 100 pero no por 400.
#
# Ejemplos:
# - `es_bisiesto(2020)` → `True`
# - `es_bisiesto(1900)` → `False`
# - `es_bisiesto(2000)` → `True`

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Diseño de casos de prueba
#
# Diseña casos de prueba (caja negra) para una función `raiz_cuadrada(x, epsilon)` que devuelve una aproximación de $\sqrt{x}$ con error menor que `epsilon`. Indica al menos cuatro casos distintos, incluyendo un caso límite. No es necesario implementar la función.

# %%
# Tu solución aquí (puedes escribir los casos como comentarios o como asserts)

# %% [markdown]
# ## Ejercicio 5: IMC con validación
#
# La siguiente función calcula el índice de masa corporal (IMC). Añade `assert` para validar las precondiciones y escribe tres casos de prueba.
#
# ```python
# def imc(peso, altura):
#     return peso / (altura ** 2)
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: assert vs raise
#
# Reflexiona: ¿por qué no es buena idea usar `assert` para validar entradas introducidas por un usuario en un programa en producción? Escribe una alternativa segura usando `if`/`raise`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
