# %% [markdown]
# # Tema 3.3: Ejercicios
#
# Estructuras condicionales
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Clasificación de triángulos
#
# Define `clasifica_triangulo(a, b, c)` que reciba las longitudes de los tres lados de un triángulo y devuelva `"Equilátero"`, `"Isósceles"` o `"Escaleno"`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Año bisiesto
#
# Define `es_bisiesto(año)` que devuelva `True` si el año es bisiesto. Reglas: es bisiesto si es divisible por 4, **excepto** si es divisible por 100; pero **sí** es bisiesto si es divisible por 400. (Así, 2000 fue bisiesto, pero 1900 no lo fue.)

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Conversión de temperatura
#
# Define `convertir_temperatura(valor, unidad_origen)` que reciba una temperatura y una unidad (`"C"` o `"F"`), y devuelva la temperatura convertida a la otra unidad. Fórmulas: $F = C \cdot 9/5 + 32$; $C = (F - 32) \cdot 5/9$.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Precio de un billete de autobús
#
# Define `precio_billete(km, num_pasajeros)` según estas reglas: precio base **8 €** por persona hasta 200 km; para trayectos > 200 km, **+0,03 €/km** por cada km por encima de 200, hasta un máximo de 400 km; si el número de pasajeros es **3 o más**, se aplica un **10 % de descuento** sobre el total.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Calculadora con operador textual
#
# Define `calculadora(a, b, op)` que reciba dos números y un operador (`"+"`, `"-"`, `"*"`, `"/"`, `"**"`) y devuelva el resultado. Si el operador no es válido, devuelve `None`. Para la división, comprueba que `b != 0` y devuelve `None` si lo es.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Descuento por tramos
#
# Define `calcular_descuento(precio)`: si `precio < 50`, 0 %; `50 ≤ precio < 100`, 5 %; `100 ≤ precio < 500`, 10 %; `precio ≥ 500`, 20 %. Devuelve el precio final tras aplicar el descuento.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 7: Reloj 12 h
#
# Define `reloj_12h(hora_24)` que reciba una hora en formato 24h (entero 0–23) y devuelva una cadena con la hora en formato 12h seguida de `"AM"` o `"PM"`. Ejemplos: `0 → "12 AM"`, `13 → "1 PM"`, `23 → "11 PM"`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 8: Cinco vocales distintas
#
# Define `contiene_5_vocales(palabra)` que devuelva `True` si la palabra contiene las **cinco vocales** distintas (`a, e, i, o, u`), sin distinción de mayúsculas. Ejemplos: `"murciélago"` → `True`, `"hola"` → `False`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
