# %% [markdown]
# # Tema 3.4: Ejercicios
#
# Estructuras de repetición
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Sucesión de Fibonacci
#
# Define `fibonacci(n)` que imprima los **`n` primeros términos** de Fibonacci, donde $F_0 = 0$, $F_1 = 1$ y $F_k = F_{k-1} + F_{k-2}$. Ejemplo: `fibonacci(7)` imprime `0 1 1 2 3 5 8`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Suma de divisores propios
#
# Define `suma_de_divisores_propios(n)` que devuelva la suma de los **divisores propios** de `n` (todos los divisores positivos de `n` menos el propio `n`). Por ejemplo, los de 12 son `1, 2, 3, 4, 6` y su suma es `16`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Números amigos
#
# Dos números `a` y `b` son **amigos** si la suma de los divisores propios de `a` es igual a `b`, y la de `b` es igual a `a`. El par más conocido es `(220, 284)`. Define `son_amigos(a, b)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Números abundantes
#
# Un número es **abundante** si la suma de sus divisores propios es **mayor** que el propio número. Define `es_abundante(n)`. Los primeros abundantes son `12, 18, 20, 24, 30, 36, …`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Test de primalidad
#
# Define `es_primo(n)` que devuelva `True` si `n` es primo. Un número es primo si **solo** es divisible por `1` y por sí mismo.
#
# *Pista:* Basta con probar divisores hasta $\sqrt{n}$, porque si $n = a \cdot b$, al menos uno de los dos es $\le \sqrt{n}$.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 6: Primos gemelos
#
# Define `primos_gemelos(hasta)` que devuelva una lista de pares `(p, p+2)` de **primos gemelos** menores o iguales que `hasta`. Por ejemplo: `(3, 5)`, `(5, 7)`, `(11, 13)`, …

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 7: Números de Armstrong
#
# Un número es de **Armstrong** (de orden `k`) si la suma de sus dígitos elevados a `k` (donde `k` es el número de dígitos) es igual al propio número. Por ejemplo, `153` lo es porque $1^3 + 5^3 + 3^3 = 153$. Define `es_armstrong(n)` que funcione para cualquier número de dígitos.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 8: Números de Kaprekar
#
# Un número es de **Kaprekar** si su cuadrado se puede partir en dos partes cuya suma es el propio número. Por ejemplo, $45^2 = 2025$ y $20 + 25 = 45$. Define `es_kaprekar(n)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 9: Números de Harshad
#
# Un número es de **Harshad** (o de Niven) si es divisible por la suma de sus dígitos. Por ejemplo, `18` lo es porque $1 + 8 = 9$ y $18/9 = 2$. Define `es_harshad(n)`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 10: π de Leibniz hasta una tolerancia
#
# Aproxima $\pi$ con la serie de Leibniz y devuelve cuántos términos hacen falta para que el error sea menor que `tolerancia` (p. ej. `0.001`). Define `pi_leibniz_hasta(tolerancia)` que devuelva una tupla `(n_terms, valor_aproximado)`.
#
# *Pista:* Usa un `while True` con `return` como salida y comprueba `abs(aproximacion - math.pi) < tolerancia`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
