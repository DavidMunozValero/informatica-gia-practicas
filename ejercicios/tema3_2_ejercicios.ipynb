# %% [markdown]
# # Tema 3.2: Ejercicios
#
# Tipos de datos y expresiones
#
# **Informática · Grado en Ingeniería Aeroespacial · UCLM**
# Curso 2026/27
#
# > **Instrucciones:** Guarda una copia de este notebook en tu Google Drive (**Archivo > Guardar una copia en Drive**) y resuelve los ejercicios en las celdas indicadas. Cada ejercicio tiene una celda de código vacía para tu solución.
#
# Los enunciados corresponden a los ejercicios del tema en la plataforma docente; allí encontrarás además una zona de pruebas en el navegador y la solución desplegable.

# %% [markdown]
# ## Ejercicio 1: Minutos a horas enteras
#
# Escribe una función `minutos_a_horas(minutos)` que reciba un número entero de minutos y devuelva el número de **horas enteras** equivalentes (sin decimales). Por ejemplo, `minutos_a_horas(80)` debe devolver `1`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 2: Funciones matemáticas
#
# Define dos funciones que implementen expresiones matemáticas:
#
# - `funcion2(x)`, que devuelva $y = (x-1)^2$
# - `funcion3(a, b)`, que devuelva $y = a \cdot (a+b)^2$
#
# Por ejemplo, `funcion2(7)` debe devolver `36` y `funcion3(3, 6)` debe devolver `243`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 3: Hipotenusa (Pitágoras)
#
# Define `hipotenusa(a, b)` que calcule la hipotenusa de un triángulo rectángulo de catetos `a` y `b` usando el teorema de Pitágoras ($h = \sqrt{a^2 + b^2}$). Usa `math.sqrt`.

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 4: Conversión de grados y radianes
#
# Define dos funciones: `grados_a_radianes(g)` y `radianes_a_grados(r)`, usando `math.pi`. Comprueba que `radianes_a_grados(grados_a_radianes(45)) == 45` (salvo error de coma flotante).

# %%
# Tu solución aquí

# %% [markdown]
# ## Ejercicio 5: Volumen de un tronco de cono (tobera)
#
# Define `volumen_tronco_cono(R, r, h)` con $V = \frac{1}{3}\pi h (R^2 + Rr + r^2)$. Calcula el volumen de una tobera de `R = 1.2` m, `r = 0.4` m, `h = 2.0` m. Si quieres redondear el resultado, usa la función integrada `round(V, 3)`.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# **Departamento de Tecnologías y Sistemas de Información**
# Escuela de Ingeniería Industrial y Aeroespacial de Toledo — UCLM
